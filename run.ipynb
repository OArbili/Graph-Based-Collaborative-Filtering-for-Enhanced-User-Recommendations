# %% [markdown]
# # Graph-Based Collaborative Filtering with Enhanced User Recommendations
# ## Example Running Configuration (Test)
#
# ### This notebook demonstrates how to run the enhanced Graph Neural Network model for recommendation systems. This configuration uses 100 negative samples per positive interaction for faster testing and initial experimentation.
#
# ### Note: This is a lightweight configuration for quick testing. For optimal performance as reported in the paper, use the configuration with 2000 negative sampling

# %%
# !python src/run.py --config_file ./configs/amazonbooks_m1-100-pre.ini
# Out:
# started
# ###################### MultiAspectGraph ######################
# ./configs/amazonbooks_m1-100-pre.ini
# load path = ./amazon_ii_constraint_mat object
# load path = ./amazon_ii_neighbor_mat object
# Load Configuration OK, show them below
# Configuration:
# {'embedding_dim': 64, 'ii_neighbor_num': 10, 'model_save_path': './amazon.pt', 'max_epoch': 2000, 'enable_tensorboard': True, 'initial_weight': 0.0001, 'dataset': 'amazon', 'gpu': '0', 'device': device(type='cuda'), 'lr': 0.001, 'batch_size': 1024, 'early_stop_epoch': 15, 'w1': 1e-08, 'w2': 1.0, 'w3': 1.0, 'w4': 1e-08, 'negative_num': 100, 'negative_weight': 100.0, 'gamma': 0.0001, 'lambda': 2.75, 'sampling_sift_pos': False, 'test_batch_size': 2048, 'topk': 20, 'user_num': 52643, 'item_num': 91599}
# start load weight
# torch.Size([52643, 64])
# torch.Size([91599, 64])
# end load weight
# before train
# cuda
# Using device: cuda
# Total training batches = 4650
# ...
